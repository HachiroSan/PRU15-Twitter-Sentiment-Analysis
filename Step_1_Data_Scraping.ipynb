# %%
import pandas as pd

df = pd.read_csv("Politician Twitter.csv")
df
# Out:
#            username                        Name  Political Party
# 0    chedetofficial                    Mahathir              NaN
# 1      anwaribrahim               Anuar Ibrahim              NaN
# 2        NajibRazak                 Najib Razak              NaN
# 3          Khairykj         Khairy Jalamaluddin              NaN
# 4        NgaKorMing                Nga Kor Ming              NaN
# 5       anthonyloke              Loke Siew Fook              NaN
# 6       TeoNieChing               Nie Ching Teo              NaN
# 7    GobindSinghDeo              GobindSinghDeo              NaN
# 8        hannahyeoh                 Hannah Yeoh              NaN
# 9            DrDzul             Dzulkefly Ahmad              NaN
# 10     fahmi_fadzil                Fahmi Fadzil              NaN
# 11       scheekeong                  Steven Sim              NaN
# 12   abdulhadiawang            Abdul Hadi Awang              NaN
# ...

# %% [markdown]
# Keywords for netizen data
# These words will be used for scraping the entire twitter data
#
# 1. PRU15
# 2. Barisan Nasional'
# 3. Gerakan Tanah Air
# 4. Pakatan Harapan
# 5. Perikatan Nasional
# 6. "Undi Warisan"
# 7. GE15
# 8. "Pilihan Raya Umum"

# %%
df.drop(['Political Party'], axis=1)
# Out:
#            username                        Name
# 0    chedetofficial                    Mahathir
# 1      anwaribrahim               Anuar Ibrahim
# 2        NajibRazak                 Najib Razak
# 3          Khairykj         Khairy Jalamaluddin
# 4        NgaKorMing                Nga Kor Ming
# 5       anthonyloke              Loke Siew Fook
# 6       TeoNieChing               Nie Ching Teo
# 7    GobindSinghDeo              GobindSinghDeo
# 8        hannahyeoh                 Hannah Yeoh
# 9            DrDzul             Dzulkefly Ahmad
# 10     fahmi_fadzil                Fahmi Fadzil
# 11       scheekeong                  Steven Sim
# 12   abdulhadiawang            Abdul Hadi Awang
# 13         AdamAdli                   Adam Adli
# 14   FadhlinaSiddiq              Fadhlina Sidek
# 15      lim_weijiet                Lim Wei Jiet
# 16     liowtionglai                  Uncle Liow
# 17     diraabuzahar  Datuk Khaidhirah Abu Zahar
# 18   AzalinaOthmanS         Azalina Othman Said
# ...

# %%
# Use a good old library for this task
# !git clone https://github.com/marquisvictor/Optimized-Modified-GetOldTweets3-OMGOT.git
# Out:
# Cloning into 'Optimized-Modified-GetOldTweets3-OMGOT'...
# remote: Enumerating objects: 366, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 366 (delta 31), reused 23 (delta 13), pack-reused 291
# Receiving objects: 100% (366/366), 609.59 KiB | 2.45 MiB/s, done.
# Resolving deltas: 100% (111/111), done.

# %%
# Install requirements.txt
# !pip install -r "/content/Optimized-Modified-GetOldTweets3-OMGOT/GetOldTweets3-0.0.10/requirements.txt"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.5 MB 7.0 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 50.1 MB/s
# ...
#      |████████████████████████████████| 49 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 115 kB 52.7 MB/s
# ...
#      |████████████████████████████████| 265 kB 58.5 MB/s
# ...
#      |████████████████████████████████| 147 kB 61.3 MB/s
# ...
#      |████████████████████████████████| 411 kB 53.2 MB/s
# ...
#      |████████████████████████████████| 178 kB 57.7 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 335 kB 52.4 MB/s
# ...
#      |████████████████████████████████| 146 kB 52.1 MB/s
# ...
#      |████████████████████████████████| 334 kB 56.1 MB/s
# ...
#      |████████████████████████████████| 94 kB 3.5 MB/s
# ...
#      |████████████████████████████████| 112 kB 62.9 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.1 MB/s
# ...

# %%
# !pip install fake-useragent
# !pip install aiohttp-socks
# !pip install googletransx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached googletransx-2.4.2.tar.gz (13 kB)
# ...
#   Created wheel for googletransx: filename=googletransx-2.4.2-py3-none-any.whl size=15968 sha256=f9feb021a7512b82f2d477616ffef91d1ca6119eab175b4074b980877d8f9e8e
#   Stored in directory: /root/.cache/pip/wheels/6a/54/98/96b62f08dd73eca3147e36b5099d77c3f8fedc5472bb488167
# Successfully built googletransx
# ...

# %%
# Set duration of the tweets
SINCE = "2022-11-01"
UNTIL = "2022-11-30"
PATH = "/content/Optimized-Modified-GetOldTweets3-OMGOT/GetOldTweets3-0.0.10/cli.py"


for i in df['username']:
  command = f"!python {PATH} --username {i} --since {SINCE} --until {UNTIL} -o {i}.csv --csv"
  print(command)

# Take these commands below and just copy paste into new block of code. It will generate all the csv with username mentioned
# Out:
# !python /content/Optimized-Modified-GetOldTweets3-OMGOT/GetOldTweets3-0.0.10/cli.py --username chedetofficial --since 2022-11-01 --until 2022-11-30 -o chedetofficial.csv --csv
# !python /content/Optimized-Modified-GetOldTweets3-OMGOT/GetOldTweets3-0.0.10/cli.py --username anwaribrahim --since 2022-11-01 --until 2022-11-30 -o anwaribrahim.csv --csv
# !python /content/Optimized-Modified-GetOldTweets3-OMGOT/GetOldTweets3-0.0.10/cli.py --username NajibRazak --since 2022-11-01 --until 2022-11-30 -o NajibRazak.csv --csv
# !python /content/Optimized-Modified-GetOldTweets3-OMGOT/GetOldTweets3-0.0.10/cli.py --username Khairykj --since 2022-11-01 --until 2022-11-30 -o Khairykj.csv --csv
# !python /content/Optimized-Modified-GetOldTweets3-OMGOT/GetOldTweets3-0.0.10/cli.py --username NgaKorMing --since 2022-11-01 --until 2022-11-30 -o NgaKorMing.csv --csv
# ...

# %%
# !python /content/Optimized-Modified-GetOldTweets3-OMGOT/GetOldTweets3-0.0.10/cli.py --username chedetofficial --since 2022-11-01 --until 2022-11-30 -o chedetofficial.csv --csv
# !python /content/Optimized-Modified-GetOldTweets3-OMGOT/GetOldTweets3-0.0.10/cli.py --username anwaribrahim --since 2022-11-01 --until 2022-11-30 -o anwaribrahim.csv --csv
# Out:
# 1596369835336019969 2022-11-26 05:06:42 +0000 <chedetofficial> Assalammualaikum warahmatullahi wabarakatuh dan salam sejahtera.  Saya mengutus surat ini untuk 4,566 pengundi-pengundi yang telah memberi undi mereka kepada saya di dalam PRU ke-15 untuk kerusi parlimen Langkawi. https://t.co/ryJT1mz8Hs
# 1596090626050641921 2022-11-25 10:37:13 +0000 <chedetofficial> I received a visit from Mr. Ajmal Shams who was  formerly Deputy Minister in the Government of the Islamic Republic of Afghanistan.  We shared views on the current state of the Muslim ummah and the need to promote better understanding of the teachings of the Quran among the ummah https://t.co/qt0u8VUMoN
# 1596078097714946049 2022-11-25 09:47:26 +0000 <chedetofficial> They are in Malaysia on an educational field trip to learn more about Malaysia's socioeconomic policies and the role of various sectors in achieving Malaysia's development agenda. https://t.co/MhaC0yAon5
# ...
